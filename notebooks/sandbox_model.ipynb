# %%
import numpy as np
import torch

wavegrid = np.load(
    "/home/tliopis/Codes/exoplanets_llopis_mary_2025/data/soap_gpu_paper/wavegrid.npy"
)

wavegrid.max() - wavegrid.min()

40 * (wavegrid.max() - wavegrid.min())

new_wavegrid = np.linspace(wavegrid.min(), wavegrid.max(), 109484)

np.save("/home/tliopis/Codes/exoplanets_llopis_mary_2025/data/soap_gpu_paper/wavegrid_2000.npy", new_wavegrid)

# %%
time_values = np.arange(3297)

time_values = np.delete(time_values, [246, 249, 1196, 1453, 2176])

time_values.shape

np.save("/home/tliopis/Codes/exoplanets_llopis_mary_2025/data/soap_gpu_paper/time_values.npy", time_values)

# %%
import h5py
spectra_filepath = "/home/tliopis/Codes/exoplanets_llopis_mary_2025/data/soap_gpu_paper/spec_cube_tot.h5"
with h5py.File(spectra_filepath, "r") as f:
    n_file_total = f["spec_cube"].shape[0]
    print(n_file_total)
# Out:
# 3297
